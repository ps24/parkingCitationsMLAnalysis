# %% [markdown]
# #  Data Clean Up
#
# *  Remove unnecessary index
# *  Encode Location
# *  Sum and group time + location
# *  High / Low Risks

# %% [markdown]
# # Package Imports

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

#  Data dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [16, 10]
import seaborn as sns
import xgboost
from sklearn.model_selection import train_test_split

# %% [markdown]
# #  Get Data from GDrive

# %%
#  Authenticate Google Account for GDrive access (raw data is saved in GDrive)
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Raw data file gdrive location: 1n3_bCYonqpT-me4g7v7TlO80PVbaV9HR
clean_data_downloaded = drive.CreateFile({'id': '1n3_bCYonqpT-me4g7v7TlO80PVbaV9HR'})
clean_data_downloaded.GetContentFile('cleanData2.csv')

df_cleanData = pd.read_csv('cleanData2.csv', dtype={'Ticket number': str})

# %% [markdown]
# #  Data Assessment

# %%
df_cleanData.head()
# Out:
#    Unnamed: 0 Ticket number           Issue Date  Issue time RP State Plate  \
# 0           0    1103341116  2015-12-21T00:00:00      1251.0             CA
# 1           1    1103700150  2015-12-21T00:00:00      1435.0             CA
# 2           2    1104803000  2015-12-21T00:00:00      2055.0             CA
# 3           3    1104820732  2015-12-26T00:00:00      1515.0             CA
# 4           4    1105461453  2015-09-15T00:00:00       115.0             CA
#
#    Make Body Style Color            Location  Route  Agency Violation code  \
# 0  HOND         PA    GY     13147 WELBY WAY  01521     1.0         4000A1
# 1   GMC         VN    WH       525 S MAIN ST   1C51     1.0         4000A1
# 2  NISS         PA    BK       200 WORLD WAY    2R2     2.0           8939
# 3  ACUR         PA    WH       100 WORLD WAY   2F11     2.0            000
# 4  CHEV         PA    BK  GEORGIA ST OLYMPIC  1FB70     1.0          8069A
#
#   Violation Description  Fine amount  Issue_Hour  Issue_Year  Issue_Month  \
# 0    NO EVIDENCE OF REG         50.0        12.0        2015           12
# 1    NO EVIDENCE OF REG         50.0        14.0        2015           12
# 2            WHITE CURB         58.0        20.0        2015           12
# 3                17104h          NaN        15.0        2015           12
# 4  NO STOPPING/STANDING         93.0         1.0        2015            9
#
#   Issue_Month_Year Issue_Weekday   Modified_Location
# 0          2015-12        Monday           WELBY WAY
# 1          2015-12        Monday           S MAIN ST
# 2          2015-12        Monday           WORLD WAY
# 3          2015-12      Saturday           WORLD WAY
# 4          2015-09       Tuesday  GEORGIA ST OLYMPIC

# %%
df_cleanData.dtypes
# Out:
# Unnamed: 0                 int64
# Ticket number             object
# Issue Date                object
# Issue time               float64
# RP State Plate            object
# Make                      object
# Body Style                object
# Color                     object
# Location                  object
# Route                     object
# Agency                   float64
# Violation code            object
# Violation Description     object
# Fine amount              float64
# Issue_Hour               float64
# Issue_Year                 int64
# Issue_Month                int64
# Issue_Month_Year          object
# Issue_Weekday             object
# Modified_Location         object
# dtype: object

# %%
df_cleanData.shape
# Out:
# (6751096, 20)

# %%
#  Remove Unnecessary Index
df_cleanData.drop('Unnamed: 0', axis=1, inplace=True)
df_cleanData.head()
# Out:
#   Ticket number           Issue Date  Issue time RP State Plate  Make  \
# 0    1103341116  2015-12-21T00:00:00      1251.0             CA  HOND
# 1    1103700150  2015-12-21T00:00:00      1435.0             CA   GMC
# 2    1104803000  2015-12-21T00:00:00      2055.0             CA  NISS
# 3    1104820732  2015-12-26T00:00:00      1515.0             CA  ACUR
# 4    1105461453  2015-09-15T00:00:00       115.0             CA  CHEV
#
#   Body Style Color            Location  Route  Agency Violation code  \
# 0         PA    GY     13147 WELBY WAY  01521     1.0         4000A1
# 1         VN    WH       525 S MAIN ST   1C51     1.0         4000A1
# 2         PA    BK       200 WORLD WAY    2R2     2.0           8939
# 3         PA    WH       100 WORLD WAY   2F11     2.0            000
# 4         PA    BK  GEORGIA ST OLYMPIC  1FB70     1.0          8069A
#
#   Violation Description  Fine amount  Issue_Hour  Issue_Year  Issue_Month  \
# 0    NO EVIDENCE OF REG         50.0        12.0        2015           12
# 1    NO EVIDENCE OF REG         50.0        14.0        2015           12
# 2            WHITE CURB         58.0        20.0        2015           12
# 3                17104h          NaN        15.0        2015           12
# 4  NO STOPPING/STANDING         93.0         1.0        2015            9
#
#   Issue_Month_Year Issue_Weekday   Modified_Location
# 0          2015-12        Monday           WELBY WAY
# 1          2015-12        Monday           S MAIN ST
# 2          2015-12        Monday           WORLD WAY
# 3          2015-12      Saturday           WORLD WAY
# 4          2015-09       Tuesday  GEORGIA ST OLYMPIC

# %%
df_cleanData.shape
# Out:
# (6751096, 19)

# %%
#  Encode Modified_Location
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df_cleanData['Modified_Location_Encode'] = le.fit_transform(df_cleanData['Modified_Location'].astype(str))
df_cleanData.head()
# Out:
#   Ticket number           Issue Date  Issue time RP State Plate  Make  \
# 0    1103341116  2015-12-21T00:00:00      1251.0             CA  HOND
# 1    1103700150  2015-12-21T00:00:00      1435.0             CA   GMC
# 2    1104803000  2015-12-21T00:00:00      2055.0             CA  NISS
# 3    1104820732  2015-12-26T00:00:00      1515.0             CA  ACUR
# 4    1105461453  2015-09-15T00:00:00       115.0             CA  CHEV
#
#   Body Style Color            Location  Route  Agency Violation code  \
# 0         PA    GY     13147 WELBY WAY  01521     1.0         4000A1
# 1         VN    WH       525 S MAIN ST   1C51     1.0         4000A1
# 2         PA    BK       200 WORLD WAY    2R2     2.0           8939
# 3         PA    WH       100 WORLD WAY   2F11     2.0            000
# 4         PA    BK  GEORGIA ST OLYMPIC  1FB70     1.0          8069A
#
#   Violation Description  Fine amount  Issue_Hour  Issue_Year  Issue_Month  \
# 0    NO EVIDENCE OF REG         50.0        12.0        2015           12
# 1    NO EVIDENCE OF REG         50.0        14.0        2015           12
# 2            WHITE CURB         58.0        20.0        2015           12
# 3                17104h          NaN        15.0        2015           12
# 4  NO STOPPING/STANDING         93.0         1.0        2015            9
#
#   Issue_Month_Year Issue_Weekday   Modified_Location  Modified_Location_Encode
# 0          2015-12        Monday           WELBY WAY                     45303
# 1          2015-12        Monday           S MAIN ST                     36727
# 2          2015-12        Monday           WORLD WAY                     46336
# 3          2015-12      Saturday           WORLD WAY                     46336
# 4          2015-09       Tuesday  GEORGIA ST OLYMPIC                     63071

# %%
df_cleanData.Modified_Location_Encode.value_counts()
# Out:
# 41454    131384
# 45108     45709
# 25730     43305
# 38572     38858
# 32227     37085
# 33418     34097
# 25352     33986
# 22906     31930
# 40234     31738
# 24549     31316
# 39843     27419
# 38677     27172
# 38557     26956
# 25883     26730
# 46005     25227
# 20554     25182
# 39645     22947
# 26555     22325
# 33412     22145
# 22804     22104
# 31380     21671
# 4069      21142
# 22582     20156
# 20553     19594
# 26760     19105
# 6499      18988
# 45712     18580
# 40371     17472
# 39838     16877
# 45710     16738
#           ...
# 63465         1
# 34791         1
# 55267         1
# 34793         1
# 75743         1
# 38891         1
# 79837         1
# 71641         1
# 83923         1
# 10238         1
# 32448         1
# 6136          1
# 26614         1
# 18418         1
# 22512         1
# 42990         1
# 47084         1
# 38888         1
# 59366         1
# 63460         1
# 75742         1
# 79836         1
# 67546         1
# 71640         1
# 83922         1
# 10237         1
# 30711         1
# 16072         1
# 11978         1
# 4094          1
# Name: Modified_Location_Encode, Length: 86704, dtype: int64

# %%
len(df_cleanData.Modified_Location_Encode.unique().tolist())
# Out:
# 86704

# %%
len(df_cleanData.Modified_Location.unique().tolist())
# Out:
# 86704

# %% [markdown]
# #  Sum and group time + location

# %%
df = pd.DataFrame({'Date': ['2015-05-08', '2015-05-07', '2015-05-06', '2015-05-05', '2015-05-08', '2015-05-07', '2015-05-06', '2015-05-05'], 'Sym': ['aapl', 'aapl', 'aapl', 'aapl', 'aaww', 'aaww', 'aaww', 'aaww'], 'Data2': [11, 8, 10, 15, 110, 60, 100, 40],'Data3': [5, 8, 6, 1, 50, 100, 60, 120]})

df['Data4'] = df['Data3'].groupby(df['Date']).transform('sum')

# %%
df.head()
# Out:
#    Data2  Data3        Date   Sym  Data4
# 0     11      5  2015-05-08  aapl     55
# 1      8      8  2015-05-07  aapl    108
# 2     10      6  2015-05-06  aapl     66
# 3     15      1  2015-05-05  aapl    121
# 4    110     50  2015-05-08  aaww     55

# %%
df_cleanData['Issue_Hour_Loc_Count'] = df_cleanData['Modified_Location_Encode'].groupby(df_cleanData['Issue_Hour']).transform('value_counts')

# %%
df_cleanData.head()
# Out:
#   Ticket number           Issue Date  Issue time RP State Plate  Make  \
# 0    1103341116  2015-12-21T00:00:00      1251.0             CA  HOND
# 1    1103700150  2015-12-21T00:00:00      1435.0             CA   GMC
# 2    1104803000  2015-12-21T00:00:00      2055.0             CA  NISS
# 3    1104820732  2015-12-26T00:00:00      1515.0             CA  ACUR
# 4    1105461453  2015-09-15T00:00:00       115.0             CA  CHEV
#
#   Body Style Color            Location  Route  Agency          ...           \
# 0         PA    GY     13147 WELBY WAY  01521     1.0          ...
# 1         VN    WH       525 S MAIN ST   1C51     1.0          ...
# 2         PA    BK       200 WORLD WAY    2R2     2.0          ...
# 3         PA    WH       100 WORLD WAY   2F11     2.0          ...
# 4         PA    BK  GEORGIA ST OLYMPIC  1FB70     1.0          ...
#
#   Violation Description Fine amount  Issue_Hour  Issue_Year  Issue_Month  \
# 0    NO EVIDENCE OF REG        50.0        12.0        2015           12
# 1    NO EVIDENCE OF REG        50.0        14.0        2015           12
# 2            WHITE CURB        58.0        20.0        2015           12
# 3                17104h         NaN        15.0        2015           12
# 4  NO STOPPING/STANDING        93.0         1.0        2015            9
#
#    Issue_Month_Year Issue_Weekday   Modified_Location  \
# 0           2015-12        Monday           WELBY WAY
# 1           2015-12        Monday           S MAIN ST
# 2           2015-12        Monday           WORLD WAY
# 3           2015-12      Saturday           WORLD WAY
# 4           2015-09       Tuesday  GEORGIA ST OLYMPIC
#
#   Modified_Location_Encode  Issue_Hour_Loc_Count
# 0                    45303                   505
# 1                    36727                   425
# 2                    46336                   347
# 3                    46336                   404
# 4                    63071                  1332
#
# [5 rows x 21 columns]

# %%
df_cleanData[df_cleanData.Modified_Location_Encode == 36727]
# Out:
#         Ticket number           Issue Date  Issue time RP State Plate  Make  \
# 1          1103700150  2015-12-21T00:00:00      1435.0             CA   GMC
# 47777      1111383416  2016-01-05T00:00:00       219.0             CA  MAZD
# 55789      1112951770  2016-01-04T00:00:00      1957.0             CA  TOYO
# 77420      1109572752  2016-01-13T00:00:00       742.0             CA   BMW
# 77421      1109572763  2016-01-13T00:00:00       743.0             CA   BMW
# 94817      1109574395  2016-01-15T00:00:00       755.0             CA   BMW
# 108995     1113871441  2016-01-18T00:00:00      1410.0             CA  ACUR
# 108996     1113871452  2016-01-18T00:00:00      1412.0             CA  JEEP
# 117186     1111379006  2016-01-21T00:00:00       205.0             CA  HOND
# 124191     1109008014  2016-01-19T00:00:00      1715.0             CA  TOYO
# 124265     1111379091  2016-01-22T00:00:00       305.0             CA  NISS
# 124270     1111379146  2016-01-23T00:00:00       215.0             CA   BMW
# 124271     1111379150  2016-01-23T00:00:00       216.0             NV  NISS
# 124301     1111379695  2016-01-23T00:00:00       338.0             MT  PREV
# 124338     1112612944  2016-01-22T00:00:00      1303.0             CA  DAEW
# 161644     1111382296  2016-01-30T00:00:00       217.0             CA  TOYO
# 161645     1111382300  2016-01-30T00:00:00       219.0             CA  MBNZ
# 161646     1111382311  2016-01-30T00:00:00       223.0             CA  TOYO
# 161647     1111382322  2016-01-30T00:00:00       226.0             CA  MINI
# 161649     1111382344  2016-01-30T00:00:00       229.0             CA  FORD
# 161650     1111382355  2016-01-30T00:00:00       230.0             CA  LEXU
# 161656     1111382451  2016-01-31T00:00:00       210.0             CA  LEXU
# 161660     1111382495  2016-01-31T00:00:00       219.0             CA  TOYO
# 161662     1111382532  2016-01-31T00:00:00       221.0             CA  HOND
# 161670     1111382613  2016-01-31T00:00:00       238.0             CA  HYUN
# 161674     1111382650  2016-01-31T00:00:00       305.0             CA  HOND
# 161675     1111382661  2016-01-31T00:00:00       307.0             CA  NISS
# 161677     1111382683  2016-01-31T00:00:00       319.0             CA  DODG
# 168954     1108172096  2016-02-01T00:00:00      1356.0             CA  TOYO
# 183555     1109336664  2016-01-27T00:00:00      1450.0             CA  FORD
# ...               ...                  ...         ...            ...   ...
# 6613361    4338401815  2018-10-22T00:00:00      1654.0             CA  HOND
# 6613362    4338401826  2018-10-22T00:00:00      1658.0             CA  HOND
# 6613363    4338401830  2018-10-22T00:00:00      1702.0             TN  HOND
# 6637499    1126566420  2018-10-24T00:00:00       734.0             CA  NISS
# 6637500    1126566431  2018-10-24T00:00:00       742.0             CA  MITS
# 6650443    1126567621  2018-10-27T00:00:00       347.0             CA  NISS
# 6650444    1126567632  2018-10-27T00:00:00       349.0             CA  BENZ
# 6650447    1126567665  2018-10-27T00:00:00       354.0             CA   KIA
# 6680172    1116480750  2018-09-12T00:00:00       958.0             CA  LROV
# 6680174    1116480772  2018-09-12T00:00:00       959.0             CA  VOLK
# 6680404    1126032681  2018-11-03T00:00:00       425.0             CA  TOYO
# 6705964    1114332111  2018-11-01T00:00:00       800.0             CA  TOYO
# 6705966    1114332133  2018-11-01T00:00:00       930.0             CA   GMC
# 6705990    1114417356  2018-10-29T00:00:00       800.0             CA  FORD
# 6711549    1111485443  2018-11-12T00:00:00      1025.0             CA  FORD
# 6711763    1126570583  2018-11-08T00:00:00        31.0             CA   KIA
# 6711764    1126570594  2018-11-08T00:00:00        36.0             CA   BMW
# 6711803    1126571423  2018-11-09T00:00:00       514.0             CA  DODG
# 6723356    1120609840  2018-11-07T00:00:00      1240.0             CA  LEXS
# 6735773    1126556686  2018-11-18T00:00:00       402.0             CA  NISS
# 6735774    1126556690  2018-11-18T00:00:00       403.0             CA  CHEV
# 6735779    1126556815  2018-11-18T00:00:00       639.0             CA  HOND
# 6735780    1126556830  2018-11-18T00:00:00       645.0             CA  TOYO
# 6735781    1126556841  2018-11-18T00:00:00       647.0             CA  CHEV
# 6735782    1126556852  2018-11-18T00:00:00       649.0             CA  HOND
# 6741523    1114416004  2018-11-08T00:00:00       915.0             CA  CHEV
# 6741524    1114416553  2018-11-05T00:00:00       945.0             CA  LANC
# 6741739    1126557950  2018-11-19T00:00:00       720.0             CA  NISS
# 6741740    1126557961  2018-11-19T00:00:00       722.0             CA  VOLK
# 6741741    1126557972  2018-11-19T00:00:00       723.0             CA  CHEV
#
#         Body Style Color         Location  Route  Agency  \
# 1               VN    WH    525 S MAIN ST   1C51     1.0
# 47777           PA    GY    646 S MAIN ST  00601    56.0
# 55789           PA    WH   1804 S MAIN ST  00195     1.0
# 77420           PA    BL   4166 S MAIN ST  00544    55.0
# 77421           PA    BL   4166 S MAIN ST  00544    55.0
# 94817           PA    BK   8324 S MAIN ST   549A    55.0
# 108995          PA    WH   1720 S MAIN ST   207W    51.0
# 108996          PA    WH   1720 S MAIN ST   207W    51.0
# 117186          PA    GY    807 S MAIN ST  00601    56.0
# 124191          PA    GR    525 S MAIN ST   1C51     1.0
# 124265          SU    GY    409 S MAIN ST  00601    56.0
# 124270          PA    BK    700 S MAIN ST  00601    56.0
# 124271          PA    BK    700 S MAIN ST  00601    56.0
# 124301          BU    PU    450 S MAIN ST  00601    56.0
# 124338          PA    BL   4800 S MAIN ST  00547    55.0
# 161644          PA    GY    818 S MAIN ST  00600    56.0
# 161645          PA    BK    756 S MAIN ST  00600    56.0
# 161646          PA    WH    653 S MAIN ST  00600    56.0
# 161647          PA    BK    647 S MAIN ST  00600    56.0
# 161649          TR    GO    634 S MAIN ST  00600    56.0
# 161650          PA    GY    620 S MAIN ST  00600    56.0
# 161656          SU    SI    818 S MAIN ST  00600    56.0
# 161660          PA    GY    757 S MAIN ST  00600    56.0
# 161662          PA    CH    756 S MAIN ST  00601    56.0
# 161670          PA    CH    518 S MAIN ST  00601    56.0
# 161674          PA    SI    452 S MAIN ST  00601    56.0
# 161675          PA    BL    452 S MAIN ST  00601    56.0
# 161677          PA    BK    411 S MAIN ST  00601    56.0
# 168954          PA    SI    627 S MAIN ST  00681    56.0
# 183555          SU    WH   9310 S MAIN ST  25MQ6     1.0
# ...            ...   ...              ...    ...     ...
# 6613361         PA    GO   4343 S MAIN ST   549B    55.0
# 6613362         PA    GN   4607 S MAIN ST   549B    55.0
# 6613363         PA    SL   5001 S MAIN ST   549B    55.0
# 6637499         PA    GY   7318 S MAIN ST  00500    55.0
# 6637500         PA    GY   5900 S MAIN ST  00500    55.0
# 6650443         PA    GY   4310 S MAIN ST  00500    55.0
# 6650444         PA    GY   4200 S MAIN ST  00500    55.0
# 6650447         SU    RE   4301 S MAIN ST  00500    55.0
# 6680172         PA    BK    100 S MAIN ST    NaN    53.0
# 6680174         PA    RE    100 S MAIN ST    NaN    53.0
# 6680404         PA    TA   6001 S MAIN ST  00500    55.0
# 6705964         PA   NaN   7600 S MAIN ST    NaN     1.0
# 6705966         SU    BK   7600 S MAIN ST    NaN     1.0
# 6705990         PA    WH  10305 S MAIN ST     PT     1.0
# 6711549         VN    RE  10921 S MAIN ST    NaN    55.0
# 6711763         PA    GY   7410 S MAIN ST  00500    55.0
# 6711764         PA    GY   7330 S MAIN ST  00500    55.0
# 6711803         PA    GY   4001 S MAIN ST  00500    55.0
# 6723356         PA    GY    550 S MAIN ST  00154     1.0
# 6735773         PA    SI   4306 S MAIN ST  00500    55.0
# 6735774         PA    BL   4272 S MAIN ST  00500    55.0
# 6735779         PA    SI   5600 S MAIN ST  00500    55.0
# 6735780         PA    MA   5701 S MAIN ST  00500    55.0
# 6735781         TR    GY   5700 S MAIN ST  00500    55.0
# 6735782         PA    BK   5700 S MAIN ST  00500    55.0
# 6741523         TR    GY  11308 S MAIN ST  01842     1.0
# 6741524         MC    RE  11874 S MAIN ST  18SL6     1.0
# 6741739         SU    SI   6200 S MAIN ST  00500    55.0
# 6741740         SU    BL   6122 S MAIN ST  00500    55.0
# 6741741         PA    SI   5900 S MAIN ST  00500    55.0
#
#                  ...          Violation Description Fine amount  Issue_Hour  \
# 1                ...             NO EVIDENCE OF REG        50.0        14.0
# 47777            ...                     NO PARKING        73.0         2.0
# 55789            ...             NO EVIDENCE OF REG        50.0        19.0
# 77420            ...               NO STOP/STAND AM        93.0         7.0
# 77421            ...                   EXPIRED TAGS        25.0         7.0
# 94817            ...               NO STOP/STAND AM        93.0         7.0
# 108995           ...                  METER EXPIRED        63.0        14.0
# 108996           ...                  METER EXPIRED        63.0        14.0
# 117186           ...                     NO PARKING        73.0         2.0
# 124191           ...             NO EVIDENCE OF REG        50.0        17.0
# 124265           ...           NO PARK/STREET CLEAN        73.0         3.0
# 124270           ...                     NO PARKING        73.0         2.0
# 124271           ...                     NO PARKING        73.0         2.0
# 124301           ...           NO PARK/STREET CLEAN        73.0         3.0
# 124338           ...                    YELLOW ZONE        58.0        13.0
# 161644           ...                     NO PARKING        73.0         2.0
# 161645           ...                     NO PARKING        73.0         2.0
# 161646           ...                     NO PARKING        73.0         2.0
# 161647           ...                     NO PARKING        73.0         2.0
# 161649           ...                     NO PARKING        73.0         2.0
# 161650           ...                     NO PARKING        73.0         2.0
# 161656           ...                     NO PARKING        73.0         2.0
# 161660           ...                     NO PARKING        73.0         2.0
# 161662           ...                     NO PARKING        73.0         2.0
# 161670           ...                     NO PARKING        73.0         2.0
# 161674           ...           NO PARK/STREET CLEAN        73.0         3.0
# 161675           ...           NO PARK/STREET CLEAN        73.0         3.0
# 161677           ...           NO PARK/STREET CLEAN        73.0         3.0
# 168954           ...                  METER EXPIRED        63.0        13.0
# 183555           ...             NO EVIDENCE OF REG        50.0        14.0
# ...              ...                            ...         ...         ...
# 6613361          ...               NO STOP/STANDING        93.0        16.0
# 6613362          ...               NO STOP/STANDING        93.0        16.0
# 6613363          ...               NO STOP/STANDING        93.0        17.0
# 6637499          ...               NO STOP/STAND AM        93.0         7.0
# 6637500          ...               NO STOP/STAND AM        93.0         7.0
# 6650443          ...                       RED ZONE        93.0         3.0
# 6650444          ...                       RED ZONE        93.0         3.0
# 6650447          ...                       RED ZONE        93.0         3.0
# 6680172          ...                     WHITE ZONE        58.0         9.0
# 6680174          ...                   EXPIRED TAGS        25.0         9.0
# 6680404          ...                       RED ZONE        93.0         4.0
# 6705964          ...                STNDNG IN ALLEY        68.0         8.0
# 6705966          ...                STNDNG IN ALLEY        68.0         9.0
# 6705990          ...                       RED ZONE        93.0         8.0
# 6711549          ...                       RED ZONE        93.0        10.0
# 6711763          ...                       RED ZONE        93.0         0.0
# 6711764          ...                       RED ZONE        93.0         0.0
# 6711803          ...                          22514        68.0         5.0
# 6723356          ...             NO EVIDENCE OF REG        50.0        12.0
# 6735773          ...                       RED ZONE        93.0         4.0
# 6735774          ...                       RED ZONE        93.0         4.0
# 6735779          ...                       RED ZONE        93.0         6.0
# 6735780          ...                       RED ZONE        93.0         6.0
# 6735781          ...                       RED ZONE        93.0         6.0
# 6735782          ...                       RED ZONE        93.0         6.0
# 6741523          ...             NO EVIDENCE OF REG        50.0         9.0
# 6741524          ...                         22500F        68.0         9.0
# 6741739          ...               NO STOP/STAND AM        93.0         7.0
# 6741740          ...               NO STOP/STAND AM        93.0         7.0
# 6741741          ...               NO STOP/STAND AM        93.0         7.0
#
#          Issue_Year  Issue_Month  Issue_Month_Year Issue_Weekday  \
# 1              2015           12           2015-12        Monday
# 47777          2016            1           2016-01       Tuesday
# 55789          2016            1           2016-01        Monday
# 77420          2016            1           2016-01     Wednesday
# 77421          2016            1           2016-01     Wednesday
# 94817          2016            1           2016-01        Friday
# 108995         2016            1           2016-01        Monday
# 108996         2016            1           2016-01        Monday
# 117186         2016            1           2016-01      Thursday
# 124191         2016            1           2016-01       Tuesday
# 124265         2016            1           2016-01        Friday
# 124270         2016            1           2016-01      Saturday
# 124271         2016            1           2016-01      Saturday
# 124301         2016            1           2016-01      Saturday
# 124338         2016            1           2016-01        Friday
# 161644         2016            1           2016-01      Saturday
# 161645         2016            1           2016-01      Saturday
# 161646         2016            1           2016-01      Saturday
# 161647         2016            1           2016-01      Saturday
# 161649         2016            1           2016-01      Saturday
# 161650         2016            1           2016-01      Saturday
# 161656         2016            1           2016-01        Sunday
# 161660         2016            1           2016-01        Sunday
# 161662         2016            1           2016-01        Sunday
# 161670         2016            1           2016-01        Sunday
# 161674         2016            1           2016-01        Sunday
# 161675         2016            1           2016-01        Sunday
# 161677         2016            1           2016-01        Sunday
# 168954         2016            2           2016-02        Monday
# 183555         2016            1           2016-01     Wednesday
# ...             ...          ...               ...           ...
# 6613361        2018           10           2018-10        Monday
# 6613362        2018           10           2018-10        Monday
# 6613363        2018           10           2018-10        Monday
# 6637499        2018           10           2018-10     Wednesday
# 6637500        2018           10           2018-10     Wednesday
# 6650443        2018           10           2018-10      Saturday
# 6650444        2018           10           2018-10      Saturday
# 6650447        2018           10           2018-10      Saturday
# 6680172        2018            9           2018-09     Wednesday
# 6680174        2018            9           2018-09     Wednesday
# 6680404        2018           11           2018-11      Saturday
# 6705964        2018           11           2018-11      Thursday
# 6705966        2018           11           2018-11      Thursday
# 6705990        2018           10           2018-10        Monday
# 6711549        2018           11           2018-11        Monday
# 6711763        2018           11           2018-11      Thursday
# 6711764        2018           11           2018-11      Thursday
# 6711803        2018           11           2018-11        Friday
# 6723356        2018           11           2018-11     Wednesday
# 6735773        2018           11           2018-11        Sunday
# 6735774        2018           11           2018-11        Sunday
# 6735779        2018           11           2018-11        Sunday
# 6735780        2018           11           2018-11        Sunday
# 6735781        2018           11           2018-11        Sunday
# 6735782        2018           11           2018-11        Sunday
# 6741523        2018           11           2018-11      Thursday
# 6741524        2018           11           2018-11        Monday
# 6741739        2018           11           2018-11        Monday
# 6741740        2018           11           2018-11        Monday
# 6741741        2018           11           2018-11        Monday
#
#         Modified_Location Modified_Location_Encode  Issue_Hour_Loc_Count
# 1               S MAIN ST                    36727                   425
# 47777           S MAIN ST                    36727                  1127
# 55789           S MAIN ST                    36727                   358
# 77420           S MAIN ST                    36727                   612
# 77421           S MAIN ST                    36727                   612
# 94817           S MAIN ST                    36727                   612
# 108995          S MAIN ST                    36727                   425
# 108996          S MAIN ST                    36727                   425
# 117186          S MAIN ST                    36727                  1127
# 124191          S MAIN ST                    36727                   380
# 124265          S MAIN ST                    36727                  1118
# 124270          S MAIN ST                    36727                  1127
# 124271          S MAIN ST                    36727                  1127
# 124301          S MAIN ST                    36727                  1118
# 124338          S MAIN ST                    36727                   438
# 161644          S MAIN ST                    36727                  1127
# 161645          S MAIN ST                    36727                  1127
# 161646          S MAIN ST                    36727                  1127
# 161647          S MAIN ST                    36727                  1127
# 161649          S MAIN ST                    36727                  1127
# 161650          S MAIN ST                    36727                  1127
# 161656          S MAIN ST                    36727                  1127
# 161660          S MAIN ST                    36727                  1127
# 161662          S MAIN ST                    36727                  1127
# 161670          S MAIN ST                    36727                  1127
# 161674          S MAIN ST                    36727                  1118
# 161675          S MAIN ST                    36727                  1118
# 161677          S MAIN ST                    36727                  1118
# 168954          S MAIN ST                    36727                   438
# 183555          S MAIN ST                    36727                   425
# ...                   ...                      ...                   ...
# 6613361         S MAIN ST                    36727                   390
# 6613362         S MAIN ST                    36727                   390
# 6613363         S MAIN ST                    36727                   380
# 6637499         S MAIN ST                    36727                   612
# 6637500         S MAIN ST                    36727                   612
# 6650443         S MAIN ST                    36727                  1118
# 6650444         S MAIN ST                    36727                  1118
# 6650447         S MAIN ST                    36727                  1118
# 6680172         S MAIN ST                    36727                   531
# 6680174         S MAIN ST                    36727                   531
# 6680404         S MAIN ST                    36727                   874
# 6705964         S MAIN ST                    36727                   550
# 6705966         S MAIN ST                    36727                   531
# 6705990         S MAIN ST                    36727                   550
# 6711549         S MAIN ST                    36727                   524
# 6711763         S MAIN ST                    36727                  1856
# 6711764         S MAIN ST                    36727                  1856
# 6711803         S MAIN ST                    36727                   834
# 6723356         S MAIN ST                    36727                   505
# 6735773         S MAIN ST                    36727                   874
# 6735774         S MAIN ST                    36727                   874
# 6735779         S MAIN ST                    36727                   664
# 6735780         S MAIN ST                    36727                   664
# 6735781         S MAIN ST                    36727                   664
# 6735782         S MAIN ST                    36727                   664
# 6741523         S MAIN ST                    36727                   531
# 6741524         S MAIN ST                    36727                   531
# 6741739         S MAIN ST                    36727                   612
# 6741740         S MAIN ST                    36727                   612
# 6741741         S MAIN ST                    36727                   612
#
# [957 rows x 21 columns]

# %%
df_cleanData.Issue_Hour_Loc_Count.describe()
# Out:
# count    6.751096e+06
# mean     5.249974e+02
# std      2.193471e+02
# min      3.030000e+02
# 25%      4.040000e+02
# 50%      5.050000e+02
# 75%      5.310000e+02
# max      1.856000e+03
# Name: Issue_Hour_Loc_Count, dtype: float64

# %% [markdown]
# #  New Column:  High / Low Risks

# %%
def condition(s):
  if(s['Issue_Hour_Loc_Count'] > 500):
    return 1
  else:
    return 0

# %%
df_cleanData['t_risk_level'] = df_cleanData.apply(condition, axis=1)

# %%
df_cleanData.head()
# Out:
#   Ticket number           Issue Date  Issue time RP State Plate  Make  \
# 0    1103341116  2015-12-21T00:00:00      1251.0             CA  HOND
# 1    1103700150  2015-12-21T00:00:00      1435.0             CA   GMC
# 2    1104803000  2015-12-21T00:00:00      2055.0             CA  NISS
# 3    1104820732  2015-12-26T00:00:00      1515.0             CA  ACUR
# 4    1105461453  2015-09-15T00:00:00       115.0             CA  CHEV
#
#   Body Style Color            Location  Route  Agency      ...       \
# 0         PA    GY     13147 WELBY WAY  01521     1.0      ...
# 1         VN    WH       525 S MAIN ST   1C51     1.0      ...
# 2         PA    BK       200 WORLD WAY    2R2     2.0      ...
# 3         PA    WH       100 WORLD WAY   2F11     2.0      ...
# 4         PA    BK  GEORGIA ST OLYMPIC  1FB70     1.0      ...
#
#   Fine amount Issue_Hour  Issue_Year  Issue_Month  Issue_Month_Year  \
# 0        50.0       12.0        2015           12           2015-12
# 1        50.0       14.0        2015           12           2015-12
# 2        58.0       20.0        2015           12           2015-12
# 3         NaN       15.0        2015           12           2015-12
# 4        93.0        1.0        2015            9           2015-09
#
#    Issue_Weekday   Modified_Location Modified_Location_Encode  \
# 0         Monday           WELBY WAY                    45303
# 1         Monday           S MAIN ST                    36727
# 2         Monday           WORLD WAY                    46336
# 3       Saturday           WORLD WAY                    46336
# 4        Tuesday  GEORGIA ST OLYMPIC                    63071
#
#   Issue_Hour_Loc_Count  t_risk_level
# 0                  505             1
# 1                  425             0
# 2                  347             0
# 3                  404             0
# 4                 1332             1
#
# [5 rows x 22 columns]

# %% [markdown]
# #  Upload Encoded Dataframe as CSV --> gDrive

# %%
df_cleanData.to_csv("example3.csv")
uploaded = drive.CreateFile({'title': 'DataCleanUp.csv'})
uploaded.SetContentFile("example3.csv")
uploaded.Upload()
